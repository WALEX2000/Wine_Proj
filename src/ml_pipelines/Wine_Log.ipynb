# %% [markdown]
# # ML Pipeline: Wine_Log

# %%
import mlblocks
from mlblocks import MLPipeline
from pprint import pprint

# %%
mlblocks.find_primitives('') # Primitive Lookup function

# %%
# List of Primitives in the Pipeline (Edit as needed)
primitives = [
    'sklearn.linear_model.LogisticRegression'
]

# List of extra arguments to call each primitive with (Edit as needed)
init_params = {
'sklearn.linear_model.LogisticRegression' : {},
}

pipeline = MLPipeline(primitives=primitives, init_params=init_params)
pipeline.get_diagram()

# %%
# See Pipeline parameters
pprint(pipeline.get_hyperparameters())
# Out:
# {'sklearn.linear_model.LogisticRegression#1': {'C': 1.0,
#                                                'class_weight': None,
#                                                'dual': False,
#                                                'fit_intercept': True,
#                                                'intercept_scaling': 1,
#                                                'max_iter': 100,
#                                                'multi_class': 'ovr',
#                                                'n_jobs': None,
#                                                'penalty': 'l2',
#                                                'random_state': None,
#                                                'solver': 'liblinear',
#                                                'tol': 0.0001,
#                                                'verbose': False,
#                                                'warm_start': False}}

# %%
# Warning! Do not change the naming convention
pipeline.save('./pipeline_annotations/Wine_Log_pipeline.json')
